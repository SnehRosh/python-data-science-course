# %% [markdown]
# Analyze E-commerce dataset to identify popular products, categories and customer behavior using pandas and visualize the data using matplotlib or seaborn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import streamlit as st
import plotly.express as px

# %%
trans = pd.read_csv('C:/Users/Hp/OneDrive/Desktop/PYDS/Ecommerce_DA_app/Sales_Transactions.csv')
trans
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 2                    0                        0         General
# 3                    1                        0  General Petite
# 4                    1                        6         General
# ...                ...                      ...             ...
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# 23485                1                       22  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses
#
# [23486 rows x 11 columns]

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
trans.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# # Popular Products

# %%
px.histogram(trans, x='Class Name',y='Rating', width=800, title='Range of Rating on Clothes ')

# %% [markdown]
# # Null value visualisation

# %%
trans.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
trans.isnull().sum().plot(kind='bar',)
# Out:
# <Axes: >

# %% [markdown]
# # Total Number of rows and Columns in the dataset

# %%
trans.shape
# Out:
# (23486, 11)

# %% [markdown]
# # Dropping missing records from dataset

# %%
trans.dropna().shape
# Out:
# (19662, 11)

# %%
trans.shape
# Out:
# (23486, 11)

# %%
trans.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# # Dropping irrelevant columns

# %%
cols_to_drop=['Review Text']
trans.drop(columns=cols_to_drop, inplace=True)

# %%
cols_to_drop=['Title']
trans.drop(columns=cols_to_drop, inplace=True)

# %%
trans.head(10)
# Out:
#    Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0           0          767   33       4                1
# 1           1         1080   34       5                1
# 2           2         1077   60       3                0
# 3           3         1049   50       5                1
# 4           4          847   47       5                1
# 5           5         1080   49       2                0
# 6           6          858   39       5                1
# 7           7          858   39       4                1
# 8           8         1077   24       5                1
# 9           9         1077   34       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
# 5                        4         General         Dresses    Dresses
# 6                        1  General Petite            Tops      Knits
# 7                        4  General Petite            Tops      Knits
# 8                        0         General         Dresses    Dresses
# 9                        0         General         Dresses    Dresses

# %% [markdown]
# # Sorting dataset on a condition

# %%
trans.sort_values(by='Rating',ascending=False)
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 11743       11743          960   51       5                1
# 13393       13393         1153   39       5                1
# 13397       13397         1072   52       5                1
# 13398       13398         1094   44       5                1
# 13399       13399          927   36       5                1
# ...           ...          ...  ...     ...              ...
# 19304       19304         1103   91       1                0
# 19288       19288         1078   39       1                0
# 19283       19283          818   65       1                0
# 19275       19275          818   45       1                0
# 10147       10147          820   56       1                0
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 11743                        1         General         Jackets    Jackets
# 13393                        3         General         Dresses    Dresses
# 13397                        0         General         Dresses    Dresses
# 13398                        1  General Petite         Dresses    Dresses
# 13399                        0  General Petite            Tops   Sweaters
# ...                        ...             ...             ...        ...
# 19304                        3         General         Dresses    Dresses
# 19288                        0  General Petite         Dresses    Dresses
# 19283                        0         General            Tops    Blouses
# 19275                        2         General            Tops    Blouses
# 10147                       24  General Petite            Tops    Blouses
#
# [23486 rows x 9 columns]

# %%
top_products = trans.sort_values(by='Rating',ascending=False).head(10)
top_products
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 11743       11743          960   51       5                1
# 13393       13393         1153   39       5                1
# 13397       13397         1072   52       5                1
# 13398       13398         1094   44       5                1
# 13399       13399          927   36       5                1
# 13400       13400          927   48       5                1
# 13405       13405          864   46       5                1
# 13406       13406          927   37       5                1
# 13408       13408          927   27       5                1
# 13409       13409          864   29       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 11743                        1         General         Jackets    Jackets
# 13393                        3         General         Dresses    Dresses
# 13397                        0         General         Dresses    Dresses
# 13398                        1  General Petite         Dresses    Dresses
# 13399                        0  General Petite            Tops   Sweaters
# 13400                        0  General Petite            Tops   Sweaters
# 13405                        2  General Petite            Tops      Knits
# 13406                        0  General Petite            Tops   Sweaters
# 13408                        0  General Petite            Tops   Sweaters
# 13409                        3  General Petite            Tops      Knits

# %%
tp_list = top_products[['Clothing ID','Rating','Division Name','Class Name']]
tp_list
# Out:
#        Clothing ID  Rating   Division Name Class Name
# 11743          960       5         General    Jackets
# 13393         1153       5         General    Dresses
# 13397         1072       5         General    Dresses
# 13398         1094       5  General Petite    Dresses
# 13399          927       5  General Petite   Sweaters
# 13400          927       5  General Petite   Sweaters
# 13405          864       5  General Petite      Knits
# 13406          927       5  General Petite   Sweaters
# 13408          927       5  General Petite   Sweaters
# 13409          864       5  General Petite      Knits

# %%
px.bar(tp_list,x='Class Name',y='Clothing ID',
       title="Type of Clothing along with ID's Range",
       hover_data=['Class Name', 'Clothing ID'],
       width=500,
       color='Class Name')

# %% [markdown]
# # Representing various graph plotting

# %%
trans.head()
# Out:
#    Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0           0          767   33       4                1
# 1           1         1080   34       5                1
# 2           2         1077   60       3                0
# 3           3         1049   50       5                1
# 4           4          847   47       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
sns.scatterplot(data=trans,x='Division Name',
                y='Rating',hue='Rating', 
                palette='hot', 
                style='Division Name',
                )
# Out:
# <Axes: xlabel='Division Name', ylabel='Rating'>

# %%
sns.relplot(data=trans,
x='Division Name',
y='Rating',
hue="Rating",
style="Department Name")

# %%
sns.lineplot(data=trans,
             x='Age',
             y='Department Name',
             hue='Department Name'
            )
plt.legend()
plt.show()

# %%
trans_nan = trans.dropna()
trans_nan.shape
# Out:
# (23472, 9)

# %%
df_sun = trans[['Clothing ID','Division Name','Department Name','Class Name','Rating']].head(10)
df_sun
# Out:
#    Clothing ID   Division Name Department Name Class Name  Rating
# 0          767       Initmates        Intimate  Intimates       4
# 1         1080         General         Dresses    Dresses       5
# 2         1077         General         Dresses    Dresses       3
# 3         1049  General Petite         Bottoms      Pants       5
# 4          847         General            Tops    Blouses       5
# 5         1080         General         Dresses    Dresses       2
# 6          858  General Petite            Tops      Knits       5
# 7          858  General Petite            Tops      Knits       4
# 8         1077         General         Dresses    Dresses       5
# 9         1077         General         Dresses    Dresses       5

# %%
trans_nan = trans.dropna()
px.sunburst(
    data_frame=trans_nan,
    path=['Division Name','Department Name','Class Name'],
    values='Age',
    names=trans_nan.index,
    color='Rating',
    color_continuous_scale='RdBu'
)

# %%
trans.head()
# Out:
#    Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0           0          767   33       4                1
# 1           1         1080   34       5                1
# 2           2         1077   60       3                0
# 3           3         1049   50       5                1
# 4           4          847   47       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
trans_nan = trans.dropna()
px.treemap(
    data_frame=trans_nan,
    path=['Division Name','Department Name','Class Name'],
    values='Recommended IND',
    names=trans_nan.index
)

# %%
trans_nan.head()
# Out:
#    Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0           0          767   33       4                1
# 1           1         1080   34       5                1
# 2           2         1077   60       3                0
# 3           3         1049   50       5                1
# 4           4          847   47       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
trans['Positive Feedback Count'].plot(kind='area',figsize=(15,5))
# Out:
# <Axes: >

# %%
sns.displot(data=trans, x='Rating',hue='Department Name',binwidth=0.5)
